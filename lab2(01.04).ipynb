# %% [markdown]
# <a href="https://colab.research.google.com/github/OlegZentsov1/MMVSULAB1/blob/main/lab2(01.04).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная работа ***№2***
#
#
#
#
# *Выполнил студент группы КМА Зенцов Олег*

# %% [markdown]
# #График населения Новосибирска

# %%
import matplotlib.pyplot as plt 
import pandas as pd
from scipy.integrate import odeint 


data = {'Y': [1991, 1992, 1993, 1994, 1995],
        'P': [1446000, 1442000, 1431000, 1418000, 1399000]}
df = pd.DataFrame(data)

plt.plot(df['Y'], df['P'])

plt.xlabel('Y')
plt.ylabel('P')
plt.title('Population of Novosibirsk')

plt.show()

# %%
import numpy as np 
import matplotlib.pyplot as plt   
 

x = np.linspace(0, 100, 1000)
a=1
b=3
c=1 
y = -a*x**2 + b*x + c     

fig, ax = plt.subplots() 
ax.plot(x, y) 
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import pandas as pd
import numpy as np 
url='https://raw.githubusercontent.com/OlegZentsov1/MMVSULAB1/main/%D0%9D%D0%BE%D0%B2%D0%BE%D1%81%D0%B8%D0%B1%D0%B8%D1%80%D1%81%D0%BA.csv'
df=pd.read_csv(url)
print(df)
years=np.array(df['Years'])
population=np.array(df['Population'])
plt.plot(df['Years'], df['Population'])

plt.xlabel('Years')
plt.ylabel('Population')
plt.title('Population of Novosibirsk')

plt.show()
# Out:
#     Years  Population
# 0    1897        8000
# 1    1923       74600
# 2    1926      117863
# 3    1931      180067
# 4    1933      278000
# 5    1937      360080
# 6    1939      405297
# 7    1956      731000
# 8    1959      885045
# 9    1970     1160963
# 10   1973     1221000
# 11   1975     1285000
# 12   1976     1265000
# 13   1979     1312480
# 14   1982     1357000
# 15   1985     1357000
# 16   1986     1396000
# 17   1987     1423000
# 18   1989     1436516
# 19   1990     1427000
# 20   1991     1446000
# 21   1992     1442000
# 22   1993     1431000
# 23   1994     1418000
# 24   1995     1399000
# 25   1996     1397000
# 26   1997     1367000
# 27   1998     2732245
# 28   1999     2734031
# 29   2000     2725499
# 30   2001     2715128
# 31   2002     2703012
# 32   2003     2688423
# 33   2004     2674155
# 34   2005     2665984
# 35   2006     2654853
# 36   2007     2647195
# 37   2008     2642727
# 38   2009     2648923
# 39   2010     2661594
# ...
