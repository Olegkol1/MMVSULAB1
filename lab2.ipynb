# %% [markdown]
# <a href="https://colab.research.google.com/github/OlegZentsov1/MMVSULAB1/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная работа ***№2***
#
#
#
#
# *Выполнил студент группы КМА Зенцов Олег*

# %% [markdown]
# #График населения Новосибирска

# %%
import matplotlib.pyplot as plt 
import pandas as pd
from scipy.integrate import odeint 


data = {'Y': [1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002],
        'P': [1446000, 1442000, 1431000, 1418000, 1399000, 1397000, 1367000, 1399000, 1402400, 1398800, 1393200, 1425508]}
df = pd.DataFrame(data)

plt.plot(df['Y'], df['P'])

plt.xlabel('Y')
plt.ylabel('P')
plt.title('Population Novosibirsk')

plt.show()
