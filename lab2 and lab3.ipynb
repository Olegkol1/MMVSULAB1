# %% [markdown]
# <a href="https://colab.research.google.com/github/OlegZentsov1/MMVSULAB1/blob/main/lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Лабораторная работа ***№2***
#
#
#
#
# *Выполнил студент группы КМА Зенцов Олег*

# %% [markdown]
# #График населения Новосибирска

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
url='https://raw.githubusercontent.com/OlegZentsov1/MMVSULAB1/main/%D0%9D%D0%BE%D0%B2%D0%BE%D1%81%D0%B8%D0%B1%D0%B8%D1%80%D1%81%D0%BA.csv'
df = pd.read_csv(url)

years = np.array(df['Years']).reshape(-1, 1)
population = np.array(df['Population'])

poly_features = PolynomialFeatures(degree = 2, include_bias = False)
year_poly = poly_features.fit_transform(years)
model = LinearRegression()
model.fit(year_poly, population)
predicted_population = model.predict(year_poly)
plt.plot(years, population)
plt.plot(years, predicted_population)
plt.plot(years, population)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  k = 0.038
  return k*x
t = [1897, 1923, 1926, 1931, 1933, 1937, 1939, 1956, 1959, 1970, 1973, 1975, 1976, 1979, 1982, 1985, 1986, 1987, 1991, 1992, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
solve = odeint(dydt, 20000, t=t)
solve = solve.flatten()
# %matplotlib inline 


v = [8000, 74600, 117863, 180067, 278000, 360080, 405297, 731000, 885045, 1160963, 1221000, 1285000, 1265000, 1312480, 1357000, 1357000, 1396000, 1423000, 1446000, 1442000, 1399000, 1397000, 1367000, 1399000, 1402400, 1398800, 1393200, 1425508, 1425500, 1413000, 1405600, 1397000, 1391900, 1390500, 1397191, 1473754, 1473700, 1498921, 1523801, 1547910, 1567087, 1584138, 1602915, 1612833, 1618039, 1625631, 1633595]


plt.plot(t, solve, label = r"")
plt.plot(t, v, label = r"Население Новосибирска") 
plt.grid(True)
plt.legend()
plt.show()
