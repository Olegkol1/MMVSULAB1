# %% [markdown]
# <a href="https://colab.research.google.com/github/OlegZentsov1/MMVSULAB1/blob/main/%D0%9B%D0%B0%D0%B1%D0%BE%D1%80%D0%B0%D1%82%D0%BE%D1%80%D0%BD%D0%B0%D1%8F%2012.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа **№1**
#
#
#
#
# # **Выполнил студент группы КМА Колесников Олег**

# %% [markdown]
# #Номер 1
# $x'$*=kx*

# %%
#Номер 1 
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  k=0.42
  return k*x

t=np.linspace(0,10,100)
solve = odeint(dydt, 1, t=t)
solve = solve.flatten()
# %matplotlib inline
plt.plot(t,solve,label=r"$x'=kx$")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #Номер 2
# $x'$*=k(x)x*

# %%
#Номер 2
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def k(x):
  a=1
  b=1
  return a*x-b

def dydt(x,t):
  return k(x)*x

t=np.linspace(0,10,100)
solve = odeint(dydt, 1, t=t)
solve = solve.flatten()
# %matplotlib inline
plt.plot(t,solve,label=r"$x'=k(x)*x$")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #Номер 3
# $x'$*=k(x)x-c*

# %%
#Номер 3
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def k(x):
  a=1
  b=1
  return a*x-b

def dydt(x,t):
  c=1
  return k(x)*x-c

t=np.linspace(0,10,100)
solve = odeint(dydt, 1, t=t)
solve = solve.flatten()
# %matplotlib inline
plt.plot(t,solve,label=r"$x'=k(x)*x-c$")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# #Номер 4
# $x'$*=k(x)x-c(x)*

# %%
#Номер 4
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def k(x):
  a=1
  b=2
  return a*x-b

def c(x):
  a=5
  return a*x

def dydt(x,t):
  return k(x)*x-c(x)

t=np.linspace(0,10,100)
solve = odeint(dydt, 1, t=t)
solve = solve.flatten()
# %matplotlib inline
plt.plot(t,solve,label=r"$x'=k(x)*x-c(x)$")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Лабораторная работа №2
# # График населения Тольятти

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
url='https://raw.githubusercontent.com/Olegkol1/MMVSULAB/main/%D0%A2%D0%BE%D0%BB%D1%8C%D1%8F%D1%82%D1%82%D0%B8.csv'
df = pd.read_csv(url)

years = np.array(df['Years']).reshape(-1, 1)
population = np.array(df['Population'])

poly_features = PolynomialFeatures(degree = 2, include_bias = False)
year_poly = poly_features.fit_transform(years)
model = LinearRegression()
model.fit(year_poly, population)
predicted_population = model.predict(year_poly)
plt.plot(years, population)
plt.plot(years, predicted_population)
plt.plot(years, population)

# %% [markdown]
# # Лабораторная 3-4

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def dydt(x,t):
  k = 0.003
  return k*x
t = [1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
solve = odeint(dydt, 655000, t=t)
solve = solve.flatten()
# %matplotlib inline 


v = [655000, 666000, 678000, 689000, 701000, 708000, 712000, 715000, 720300, 722900, 724300, 702879, 702900, 703900, 704800, 704900, 705300, 705500, 720346, 719632, 719500, 719596, 719149, 718127, 719646, 712619, 710567, 707408, 702831, 699367]


plt.plot(t, solve, label = r"")
plt.plot(t, v, label = r"Население Тольятти") 
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

def euler(dydx, x, y0, n):
    y = [y0]
    for i in range(n - 1):
        xi = x[i]
        yi = y[i]
        yi1 = yi + h * dydx(yi, xi)
        y.append(yi1)
    return x, y

def dydx(x, y):
    k = 0.42
    return k * y

x0, y0 = 0, 1
h = 0.1

x = np.arange(0, 10 + h, h) 
t = np.linspace(0, 10, 100)
x, y = euler(dydx, y0 = 1, x = x, n = len(x - 1))

solve = odeint(dydx, y0 = 1, t = t)
solve = solve.flatten()



plt.plot(x, y, label = r"euler")
plt.plot(t, solve, label = r"")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Лабораторная 5

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint

x=np.linspace (0,1,100)
y=x+x*np.random.random(len(x))
A=np.vstack([x,np.ones(len(x))]).T
a,b = np.linalg.lstsq(A,y,rcond=None)[0]
plt.plot(x,y,'.')
plt.plot(x,x*a+b,'r')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import odeint
from scipy.optimize import curve_fit
x=np.linspace(-1,1,100)
y=x**2+x*np.random.random(len(x))
def f(x,a,b,c):
  return a*x**2+b*x+c
  
(a,b,c),_=curve_fit(f,x,y)
plt.plot(x,y,'.')
plt.plot (x,f(x,a,b,c), 'r')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from scipy.integrate import odeint
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge


x=np.array([-2,-1,0,1,2])
y=np.array([5,1,3,-7,4])
data=np.vstack([x,y]).T
x=x[:,np.newaxis]
x_long=np.linspace(-2,2,100)[:,np.newaxis]
model=make_pipeline(PolynomialFeatures(1),Ridge(alpha=1e-3))
model.fit(x,y)
y_predict=model.predict(x_long)

# %matplotlib inline
plt.plot(x,y,'r.')
for p in [1,2,3,4,5,6,7]:
  model=make_pipeline(PolynomialFeatures(p),Ridge(alpha=1e-3))
  model.fit(x,y)
  y_predict=model.predict(x_long)
  plt.plot(x_long,y_predict,label=str(p))
plt.grid(True)
plt.show()
